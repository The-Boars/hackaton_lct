# %% [markdown]
# Импорт библиотек

# %%
import pandas as pd
import numpy as np
import re
from transliterate import translit
import nlpaug.augmenter.char as nac
import nlpaug.augmenter.word as naw
from pathlib import Path

# %% [markdown]
# Чтение файла (запрос | выделенный из запроса товар | выделенный из запроса бренд)

# %%
df = pd.read_csv('../datasets/ofd.csv')
df = df[['name', 'good', 'brand']]
df
# Out:
#                                                     name      good  \
# 0                Petmax Бантик леопард с красн розой 2шт    бантик
# 1                       87191 Бусы для елки шарики_87191      бусы
# 2                     Футболка Piazza Italia WR011446881  футболка
# 3         7) YI572-03X-ONE ЗАКОЛКА ДЛЯ ВОЛОС ДЛЯ ДЕВОЧКИ   заколка
# 4                                      Одежда (вес) 1500    одежда
# ...                                                  ...       ...
# 34995  500 считалок, загадок, скороговорок для детей ...       NaN
# 34996         Макароны "МакСтори " перо  рефленное  400г  макароны
# 34997           2496950 [М]  Обувь зима TENDANCE 1067-3M     обувь
# 34998                   ИНГАВИРИН КАПС 1.000000 X 754.00   капсулы
# 34999      Печенье сдобное 'Американ Кукис' 180г Краферс   печенье
#
#                brand
# 0             petmax
# 1                NaN
# 2      piazza italia
# 3                NaN
# 4                NaN
# ...              ...
# 34995            NaN
# 34996       макстори
# 34997       tendance
# 34998      ингавирин
# 34999        crafers
#
# [35000 rows x 3 columns]

# %% [markdown]
# Выделение из запроса параметров volume и percent

# %%
volume_pattern = r'(\d+[,.]?\d*\s?(?:г|кг|мл|л|шт))'
percent_pattern = r'(\d+[,.]?\d*\s?(?:%|проц\.?|percent))'
df['volume'] = df['name'].str.extract(volume_pattern, flags=re.IGNORECASE)[0]
df['percent'] = df['name'].str.extract(percent_pattern, flags=re.IGNORECASE)[0]
df = df[(~df['volume'].isna()) | (~df['percent'].isna())].reset_index(drop = True)
df = df.fillna('')
df
# Out:
#                                                     name               good  \
# 0                Petmax Бантик леопард с красн розой 2шт             бантик
# 1                РУСАЛОЧКА Губка ТРИО трехслой.3 шт ЛЮКС              губка
# 2                         Квас Очаковский Пряная зима 2л               квас
# 3      Наконечник вилочный изолированный НВИ 2-6 (50ш...         наконечник
# 4                           ЧокоПай Дарк какао 6шт.Орион         товара нет
# ...                                                  ...                ...
# 16308                       Контейнер д/прод 1.2л GR1855          контейнер
# 16309                  Фасоль Нота спаржевая 10шт Гавриш             фасоль
# 16310  Глорикс 1л. сред. д/пола - Свежесть Атлантики ...  средство для пола
# 16311         Макароны "МакСтори " перо  рефленное  400г           макароны
# 16312      Печенье сдобное 'Американ Кукис' 180г Краферс            печенье
#
#             brand volume percent
# 0          petmax    2шт
# 1       русалочка   3 шт
# 2      очаковский     2л
# 3             ekf   50шт
# 4           орион    6шт
# ...           ...    ...     ...
# 16308               1.2л
# 16309      гавриш   10шт
# 16310      glorix     1л
# 16311    макстори   400г
# 16312     crafers   180г
#
# [16313 rows x 5 columns]

# %% [markdown]
# Создание нового запроса

# %%
df['query'] = (df['brand'] + ' ' + df['good'] + ' ' + df['percent'] + ' ' + df['volume']).str.replace(r'\s+', ' ', regex=True).str.strip()
df
# Out:
#                                                     name               good  \
# 0                Petmax Бантик леопард с красн розой 2шт             бантик
# 1                РУСАЛОЧКА Губка ТРИО трехслой.3 шт ЛЮКС              губка
# 2                         Квас Очаковский Пряная зима 2л               квас
# 3      Наконечник вилочный изолированный НВИ 2-6 (50ш...         наконечник
# 4                           ЧокоПай Дарк какао 6шт.Орион         товара нет
# ...                                                  ...                ...
# 16308                       Контейнер д/прод 1.2л GR1855          контейнер
# 16309                  Фасоль Нота спаржевая 10шт Гавриш             фасоль
# 16310  Глорикс 1л. сред. д/пола - Свежесть Атлантики ...  средство для пола
# 16311         Макароны "МакСтори " перо  рефленное  400г           макароны
# 16312      Печенье сдобное 'Американ Кукис' 180г Краферс            печенье
#
#             brand volume percent                        query
# 0          petmax    2шт                    petmax бантик 2шт
# 1       русалочка   3 шт                 русалочка губка 3 шт
# 2      очаковский     2л                   очаковский квас 2л
# 3             ekf   50шт                  ekf наконечник 50шт
# 4           орион    6шт                 орион товара нет 6шт
# ...           ...    ...     ...                          ...
# 16308               1.2л                       контейнер 1.2л
# 16309      гавриш   10шт                   гавриш фасоль 10шт
# 16310      glorix     1л          glorix средство для пола 1л
# 16311    макстори   400г               макстори макароны 400г
# 16312     crafers   180г                 crafers печенье 180г
#
# [16313 rows x 6 columns]

# %% [markdown]
# Функция для разметки BIO

# %%
def get_word_spans(text):
    # Возвращает список кортежей (start, end, word) по всем словам в тексте
    spans = []
    for m in re.finditer(r'\S+', text):
        spans.append((m.start(), m.end(), m.group()))
    return spans

def bio_words(text, good=None, percent=None, volume=None, brand=None):
    entities = [
        ('TYPE', good),
        ('PERCENT', percent),
        ('VOLUME', volume),
        ('BRAND', brand)
    ]
    lower_text = text.lower()
    entity_spans = []
    # Для каждой сущности ищем все вхождения в тексте (если значение задано)
    for entity, value in entities:
        if value:
            value = value.strip().lower()
            for m in re.finditer(re.escape(value), lower_text):
                entity_spans.append((m.start(), m.end(), entity))
    # Если сущности перекрывают друг друга, оставляем ту, что раньше (или по длине)
    entity_spans.sort(key=lambda x: (x[0], -(x[1]-x[0])))  # сначала по позиции, потом по длине обратной
    chosen = []
    used = [False] * len(lower_text)
    for st, en, entity in entity_spans:
        if not any(used[st:en]):  # если этот кусок ещё не размечен
            chosen.append((st, en, entity))
            for i in range(st, en):
                used[i] = True
    # BIO разметка по словам
    word_spans = get_word_spans(text)
    word_tags = ['O'] * len(word_spans)
    for st, en, entity in chosen:
        words_in_entity = []
        for idx, (w_st, w_en, _) in enumerate(word_spans):
            if w_en <= st:
                continue
            if w_st >= en:
                break
            words_in_entity.append(idx)
        if words_in_entity:
            word_tags[words_in_entity[0]] = f'B-{entity}'
            for idx in words_in_entity[1:]:
                word_tags[idx] = f'I-{entity}'
    result = []
    for idx, tag in enumerate(word_tags):
        if tag != 'O':
            w_st, w_en, _ = word_spans[idx]
            result.append((w_st, w_en, tag))
    return result

# %%
df['markup'] = df.apply(lambda row: bio_words(row['query'], row['good'], row['percent'], row['volume'], row['brand']), axis=1)
df = df[df['query'].notna() & df['query'].astype(str).str.strip().ne('')]

df
# Out:
#                                                     name               good  \
# 0                Petmax Бантик леопард с красн розой 2шт             бантик
# 1                РУСАЛОЧКА Губка ТРИО трехслой.3 шт ЛЮКС              губка
# 2                         Квас Очаковский Пряная зима 2л               квас
# 3      Наконечник вилочный изолированный НВИ 2-6 (50ш...         наконечник
# 4                           ЧокоПай Дарк какао 6шт.Орион         товара нет
# ...                                                  ...                ...
# 16308                       Контейнер д/прод 1.2л GR1855          контейнер
# 16309                  Фасоль Нота спаржевая 10шт Гавриш             фасоль
# 16310  Глорикс 1л. сред. д/пола - Свежесть Атлантики ...  средство для пола
# 16311         Макароны "МакСтори " перо  рефленное  400г           макароны
# 16312      Печенье сдобное 'Американ Кукис' 180г Краферс            печенье
#
#             brand volume percent                        query  \
# 0          petmax    2шт                    petmax бантик 2шт
# 1       русалочка   3 шт                 русалочка губка 3 шт
# 2      очаковский     2л                   очаковский квас 2л
# 3             ekf   50шт                  ekf наконечник 50шт
# 4           орион    6шт                 орион товара нет 6шт
# ...           ...    ...     ...                          ...
# 16308               1.2л                       контейнер 1.2л
# 16309      гавриш   10шт                   гавриш фасоль 10шт
# 16310      glorix     1л          glorix средство для пола 1л
# 16311    макстори   400г               макстори макароны 400г
# 16312     crafers   180г                 crafers печенье 180г
#
#                                                   markup
# 0      [(0, 6, B-BRAND), (7, 13, B-TYPE), (14, 17, B-...
# 1      [(0, 9, B-BRAND), (10, 15, B-TYPE), (16, 17, B...
# 2      [(0, 10, B-BRAND), (11, 15, B-TYPE), (16, 18, ...
# 3      [(0, 3, B-BRAND), (4, 14, B-TYPE), (15, 19, B-...
# 4      [(0, 5, B-BRAND), (6, 12, B-TYPE), (13, 16, I-...
# ...                                                  ...
# 16308               [(0, 9, B-TYPE), (10, 14, B-VOLUME)]
# 16309  [(0, 6, B-BRAND), (7, 13, B-TYPE), (14, 18, B-...
# 16310  [(0, 6, B-BRAND), (7, 15, B-TYPE), (16, 19, I-...
# 16311  [(0, 8, B-BRAND), (9, 17, B-TYPE), (18, 22, B-...
# 16312  [(0, 7, B-BRAND), (8, 15, B-TYPE), (16, 20, B-...
#
# [16313 rows x 7 columns]

# %% [markdown]
# Экспорт в csv/xlsx

# %%
# df[['query', 'markup']].to_excel('ofd.xlsx', index=False)
# df[['good', 'brand', 'percent', 'volume', 'query', 'markup']].to_excel('ofd_adv.xlsx', index=False)
df[['query', 'markup']].to_csv('../datasets/ofd_marked.csv', encoding="utf-8-sig", index=False)
# df[['good', 'brand', 'percent', 'volume', 'query', 'markup']].to_csv('ofd_adv.csv', encoding="utf-8-sig", index=False)

# %%
df_aug = df[['query', 'markup']].copy()

SEPARABLE_CHARS = {'%'}

def _insert_spaces(text: str):
    new_chars = []
    index_map = [-1] * len(text)
    for idx, ch in enumerate(text):
        if ch in SEPARABLE_CHARS:
            if new_chars and not new_chars[-1].isspace():
                new_chars.append(' ')
            index_map[idx] = len(new_chars)
            new_chars.append(ch)
            if idx + 1 < len(text) and not text[idx + 1].isspace():
                new_chars.append(' ')
        else:
            index_map[idx] = len(new_chars)
            new_chars.append(ch)
    return ''.join(new_chars), index_map

def _spans_to_char_labels(text: str, spans):
    labels = ['O'] * len(text)
    for start, end, label in spans or []:
        if not isinstance(start, int) or not isinstance(end, int):
            continue
        if start < 0 or end > len(text) or start >= end:
            continue
        if not label:
            continue
        if '-' in label:
            prefix, entity = label.split('-', 1)
        else:
            prefix, entity = 'B', label
        for pos in range(start, end):
            if pos == start:
                if prefix == 'I':
                    labels[pos] = f'I-{entity}'
                else:
                    labels[pos] = f'B-{entity}'
            else:
                labels[pos] = f'I-{entity}'
    return labels

def _char_labels_to_spans(text: str, labels):
    spans = []
    for start, end, _ in get_word_spans(text):
        tag = next((labels[pos] for pos in range(start, end) if labels[pos] != 'O'), 'O')
        if tag != 'O':
            spans.append((start, end, tag))
    return spans

def normalize_query_and_markup(text, spans):
    if not isinstance(text, str) or not text:
        return text, spans
    new_text, index_map = _insert_spaces(text)
    if new_text == text:
        return text, spans
    if not isinstance(spans, (list, tuple)):
        return new_text, spans
    spans_list = [tuple(item) for item in spans]
    char_labels_old = _spans_to_char_labels(text, spans_list)
    char_labels_new = ['O'] * len(new_text)
    for old_idx, new_idx in enumerate(index_map):
        if new_idx >= 0:
            char_labels_new[new_idx] = char_labels_old[old_idx]
    new_spans = _char_labels_to_spans(new_text, char_labels_new)
    return new_text, new_spans

def _ensure_tuple_markup(markup):
    if isinstance(markup, list):
        return [tuple(item) for item in markup]
    if isinstance(markup, tuple):
        return [markup]
    return markup

augmented_rows = []
for _, row in df_aug.iterrows():
    original_text = row['query']
    original_markup = _ensure_tuple_markup(row['markup'])
    augmented_rows.append((original_text, original_markup))
    normalized_text, normalized_markup = normalize_query_and_markup(original_text, row['markup'])
    if normalized_text != original_text or normalized_markup != row['markup']:
        normalized_markup = _ensure_tuple_markup(normalized_markup)
        augmented_rows.append((normalized_text, normalized_markup))

df_aug = pd.DataFrame(augmented_rows, columns=['query', 'markup'])

# %%
df_aug.to_csv('../datasets/ofd_marked_aug.csv', encoding="utf-8-sig", index=False)

# %% [markdown]
# Аугментация от Степы

# %%
# Russian ЙЦУКЕН keyboard layout
RU_LAYOUT = "йцукенгшщзхъфывапролджэячсмитьбю.ЙЦУКЕНГШЩЗХЪФЫВАПРОЛДЖЭЯЧСМИТЬБЮ,"

# Ukrainian keyboard layout (similar but different)
UA_LAYOUT = "йцукенгшщзхїфівапролджєячсмитьбю.ЙЦУКЕНГШЩЗХЇФІВАПРОЛДЖЄЯЧСМИТЬБЮ,"

# %%
BRAND_TAGS = ["B-BRAND", "I-BRAND"]
TYPE_TAGS = ["B-TYPE", "I-TYPE"]
VOLUME_TAGS = ["B-VOLUME", "I-VOLUME"]
PERSENT_TAGS = ["B-PERCENT", "I-PERCENT"]

# %%
def has_special(text):
    pattern = r'[!@№#$^&*()_+\-=\[\]{};\':"\\|<>/?]'

    if re.search(pattern, text):
        return True
    return False

# %%
def map_by_keyboard_position(text, from_layout, to_layout):
    """Map characters based on keyboard position"""
    translation_table = str.maketrans(from_layout, to_layout)
    return text.translate(translation_table)

# %%
def ru_to_ua(text):
    return map_by_keyboard_position(text, RU_LAYOUT, UA_LAYOUT)

def ua_to_ru(text):
    return map_by_keyboard_position(text, UA_LAYOUT, RU_LAYOUT)

# %%
def split_by_tag(text, annotations):
    """Split text into substrings according to tags"""
    segments = []

    for start, end, label in annotations:
        segments.append(text[start:end])
        last_end = end

    return segments

# %%
def crop(text, tags, crop_p):
    spl = split_by_tag(text, tags)
    probs = np.random.uniform(0, 1, len(spl))

    common_shift = 0
    new_tags = []

    for i, s in enumerate(spl):

        begin = tags[i][0] - common_shift

        if probs[i] < crop_p:
            to_del = int(np.random.uniform(.5, 1)*len(s))
            concat = s[:to_del]

            common_shift += len(s) - to_del
        else:
            concat = s

        if i > 0:
            croped = f"{croped} {concat}"

        else:
            croped = concat

        end = tags[i][1] - common_shift
        new_tags.append((begin, end, tags[i][2]))


    return croped, new_tags

# %%
def shoot(text, tags, shoot_p):
    spl = split_by_tag(text, tags)
    probs = np.random.uniform(0, 1, len(spl))

    common_shift = 0
    new_tags = []

    for i, s in enumerate(spl):
        
        begin = tags[i][0] - common_shift

        if probs[i] < shoot_p:
            to_del = int(np.random.uniform(0, 1)*len(s))
            concat = f"{s[:to_del]}{s[to_del+1:]}"

            common_shift += 1
        else:
            concat = s

        if i > 0:
            croped = f"{croped} {concat}"
        else:
            croped = concat

        end = tags[i][1] - common_shift
        new_tags.append((begin, end, tags[i][2]))

    return croped, new_tags

# %%
def char_augment(sample, n = 1, 
                 ru_typo_p = .10,
                 en_typo_p = .10,
                 swap_p = .01, 
                 crop_p = .05, 
                 shoot_p = .05):

    text, tags = sample
    augmented_tags = []
# Keyboard typo
    ua_text = ru_to_ua(text)

    aug = nac.keyboard.KeyboardAug(
                                   lang = "uk",
                                   aug_char_min = 0, 
                                   aug_char_p = ru_typo_p,
                                   aug_char_max = None, 
                                   include_upper_case = False,
                                   include_special_char = True,
                                   )
    augmented_text = aug.augment(ua_text, n = n)

    for i in range(n):

        # while has_special(augmented_text[i]):
        #     augmented_text[i] = aug.augment(text, n = 1)[0]

        augmented_text[i] = ua_to_ru(augmented_text[i])
        augmented_tags.append(tags)


    aug = nac.keyboard.KeyboardAug(
                                   lang = "en",
                                   aug_char_min = 0, 
                                   aug_char_p = en_typo_p,
                                   aug_char_max = None, 
                                   include_upper_case = False,
                                   include_special_char = False,
                                   )
    augmented_text = aug.augment(augmented_text, n = 1)

# Letters swap typo
    aug = nac.random.RandomCharAug(action="swap", 
                                   aug_char_min = 0,
                                   aug_char_p = swap_p,
                                   aug_char_max = None,
                                   swap_mode = "adjacent",
                                   include_upper_case = False)

    augmented_text = aug.augment(augmented_text, n = 1)

    for i in range(len(augmented_text)):
        augmented_text[i], augmented_tags[i] = crop(augmented_text[i], 
                                                    augmented_tags[i], 
                                                    crop_p)


    for i in range(len(augmented_text)):
        augmented_text[i], augmented_tags[i] = shoot(augmented_text[i], 
                                                     augmented_tags[i], 
                                                     shoot_p)



    return augmented_text, augmented_tags

# %%
def mix_augment(sample):
    text, tags = sample

    if len(tags) < 2:
        return [], []

    s_type = ""
    s_brand = ""
    s_volume = ""

    t_type = []
    t_brand = []
    t_volume = []

    aug_text = []
    aug_tags = []

    for begin, end, label in tags:

        if label in TYPE_TAGS or label == "O":
            s_type = f"{s_type} {text[begin:end]}"
            t_type.append((end-begin, label))

        elif label in BRAND_TAGS:
            s_brand = f"{s_brand} {text[begin:end]}"
            t_brand.append((end-begin, label))

        elif label in VOLUME_TAGS or label in PERSENT_TAGS:
            s_volume = f"{s_volume} {text[begin:end]}"
            t_volume.append((end-begin, label))

    if s_type != "":
        s_type = s_type[1:]
    if s_brand != "":
        s_brand = s_brand[1:]
    if s_volume != "":
        s_volume = s_volume[1:]


    a = (s_type == "")
    b = (s_brand == "")
    c = (s_volume == "")

    # if any two striggs empty at the same time
    # return nothing
    cond = (~a & b & c) | (a & ~b & c) | (a & b & ~c) 
    if cond:
        return [], []


    def tag_string(tags):
        tag = []
        pos = 0
        for t in tags:
            tag.append((pos, pos + t[0], t[1]))
            pos = pos + t[0] + 1

        return tag

    aug_text.append(f"{s_type} {s_brand}")
    aug_tags.append(tag_string(t_type + t_brand))

    aug_text.append(f"{s_brand} {s_type}")
    aug_tags.append(tag_string(t_brand + t_type))


    if not (s_volume == ""):
        aug_text.append(f"{s_type} {s_brand} {s_volume}")
        aug_tags.append(tag_string(t_type + t_brand + t_volume))

        aug_text.append(f"{s_type} {s_volume} {s_brand}")
        aug_tags.append(tag_string(t_type + t_volume + t_brand))

        aug_text.append(f"{s_brand} {s_type} {s_volume}")
        aug_tags.append(tag_string(t_brand + t_type + t_volume))

        aug_text.append(f"{s_type} {s_volume}")
        aug_tags.append(tag_string(t_type + t_volume))

    # find and delete original string from the list
    for i in range(len(aug_text)):
        if aug_text[i] == text:
            break

    aug_text.pop(i)
    aug_tags.pop(i)

    return aug_text, aug_tags

# %% [markdown]
# Опечатки

# %%
df_aug = pd.DataFrame()
df_test = df[['query', 'markup']]

for _, row in df_test.iterrows():
    # print(row['query'])
    orig_row = pd.DataFrame({'query': [row['query']], 'markup': [row['markup']]})
    df_aug = pd.concat([df_aug, orig_row], ignore_index=True) 
    augmented_texts, augmented_tags = char_augment(row, n=3)
    df_temp = pd.DataFrame({'query': augmented_texts, 'markup': augmented_tags})
    df_aug = pd.concat([df_aug, df_temp], ignore_index=True)
    if _ % 50 == 0:
        print(f"Processed {_} rows")

df_aug
# Out:
# Processed 0 rows
# Processed 50 rows
# Processed 100 rows
# Processed 150 rows
# Processed 200 rows
# Processed 250 rows
# Processed 300 rows
# Processed 350 rows
# Processed 400 rows
# Processed 450 rows
# Processed 500 rows
# Processed 550 rows
# Processed 600 rows
# Processed 650 rows
# Processed 700 rows
# Processed 750 rows
# Processed 800 rows
# Processed 850 rows
# Processed 900 rows
# Processed 950 rows
# Processed 1000 rows
# Processed 1050 rows
# Processed 1100 rows
# Processed 1150 rows
# Processed 1200 rows
# Processed 1250 rows
# Processed 1300 rows
# Processed 1350 rows
# Processed 1400 rows
# Processed 1450 rows
# Processed 1500 rows
# Processed 1550 rows
# Processed 1600 rows
# Processed 1650 rows
# Processed 1700 rows
# Processed 1750 rows
# Processed 1800 rows
# Processed 1850 rows
# Processed 1900 rows
# Processed 1950 rows
# Processed 2000 rows
# Processed 2050 rows
# Processed 2100 rows
# Processed 2150 rows
# Processed 2200 rows
# Processed 2250 rows
# Processed 2300 rows
# Processed 2350 rows
# Processed 2400 rows
# Processed 2450 rows
# Processed 2500 rows
# Processed 2550 rows
# Processed 2600 rows
# Processed 2650 rows
# Processed 2700 rows
# Processed 2750 rows
# Processed 2800 rows
# Processed 2850 rows
# Processed 2900 rows
# Processed 2950 rows
# Processed 3000 rows
# Processed 3050 rows
# Processed 3100 rows
# Processed 3150 rows
# Processed 3200 rows
# Processed 3250 rows
# Processed 3300 rows
# Processed 3350 rows
# Processed 3400 rows
# Processed 3450 rows
# Processed 3500 rows
# Processed 3550 rows
# Processed 3600 rows
# Processed 3650 rows
# Processed 3700 rows
# Processed 3750 rows
# Processed 3800 rows
# Processed 3850 rows
# Processed 3900 rows
# Processed 3950 rows
# Processed 4000 rows
# Processed 4050 rows
# Processed 4100 rows
# Processed 4150 rows
# Processed 4200 rows
# Processed 4250 rows
# Processed 4300 rows
# Processed 4350 rows
# Processed 4400 rows
# Processed 4450 rows
# Processed 4500 rows
# Processed 4550 rows
# Processed 4600 rows
# Processed 4650 rows
# Processed 4700 rows
# Processed 4750 rows
# Processed 4800 rows
# Processed 4850 rows
# Processed 4900 rows
# Processed 4950 rows
# Processed 5000 rows
# Processed 5050 rows
# Processed 5100 rows
# Processed 5150 rows
# Processed 5200 rows
# Processed 5250 rows
# Processed 5300 rows
# Processed 5350 rows
# Processed 5400 rows
# Processed 5450 rows
# Processed 5500 rows
# Processed 5550 rows
# Processed 5600 rows
# Processed 5650 rows
# Processed 5700 rows
# Processed 5750 rows
# Processed 5800 rows
# Processed 5850 rows
# Processed 5900 rows
# Processed 5950 rows
# Processed 6000 rows
# Processed 6050 rows
# Processed 6100 rows
# Processed 6150 rows
# Processed 6200 rows
# Processed 6250 rows
# Processed 6300 rows
# Processed 6350 rows
# Processed 6400 rows
# Processed 6450 rows
# Processed 6500 rows
# Processed 6550 rows
# Processed 6600 rows
# Processed 6650 rows
# Processed 6700 rows
# Processed 6750 rows
# Processed 6800 rows
# Processed 6850 rows
# Processed 6900 rows
# Processed 6950 rows
# Processed 7000 rows
# Processed 7050 rows
# Processed 7100 rows
# Processed 7150 rows
# Processed 7200 rows
# Processed 7250 rows
# Processed 7300 rows
# Processed 7350 rows
# Processed 7400 rows
# Processed 7450 rows
# Processed 7500 rows
# Processed 7550 rows
# Processed 7600 rows
# Processed 7650 rows
# Processed 7700 rows
# Processed 7750 rows
# Processed 7800 rows
# Processed 7850 rows
# Processed 7900 rows
# Processed 7950 rows
# Processed 8000 rows
# Processed 8050 rows
# Processed 8100 rows
# Processed 8150 rows
# Processed 8200 rows
# Processed 8250 rows
# Processed 8300 rows
# Processed 8350 rows
# Processed 8400 rows
# Processed 8450 rows
# Processed 8500 rows
# Processed 8550 rows
# Processed 8600 rows
# Processed 8650 rows
# Processed 8700 rows
# Processed 8750 rows
# Processed 8800 rows
# Processed 8850 rows
# Processed 8900 rows
# Processed 8950 rows
# Processed 9000 rows
# Processed 9050 rows
# Processed 9100 rows
# Processed 9150 rows
# Processed 9200 rows
# Processed 9250 rows
# Processed 9300 rows
# Processed 9350 rows
# Processed 9400 rows
# Processed 9450 rows
# Processed 9500 rows
# Processed 9550 rows
# Processed 9600 rows
# Processed 9650 rows
# Processed 9700 rows
# Processed 9750 rows
# Processed 9800 rows
# Processed 9850 rows
# Processed 9900 rows
# Processed 9950 rows
# Processed 10000 rows
# Processed 10050 rows
# Processed 10100 rows
# Processed 10150 rows
# Processed 10200 rows
# Processed 10250 rows
# Processed 10300 rows
# Processed 10350 rows
# Processed 10400 rows
# Processed 10450 rows
# Processed 10500 rows
# Processed 10550 rows
# Processed 10600 rows
# Processed 10650 rows
# Processed 10700 rows
# Processed 10750 rows
# Processed 10800 rows
# Processed 10850 rows
# Processed 10900 rows
# Processed 10950 rows
# Processed 11000 rows
# Processed 11050 rows
# Processed 11100 rows
# Processed 11150 rows
# Processed 11200 rows
# Processed 11250 rows
# Processed 11300 rows
# Processed 11350 rows
# Processed 11400 rows
# Processed 11450 rows
# Processed 11500 rows
# Processed 11550 rows
# Processed 11600 rows
# Processed 11650 rows
# Processed 11700 rows
# Processed 11750 rows
# Processed 11800 rows
# Processed 11850 rows
# Processed 11900 rows
# Processed 11950 rows
# Processed 12000 rows
# Processed 12050 rows
# Processed 12100 rows
# Processed 12150 rows
# Processed 12200 rows
# Processed 12250 rows
# Processed 12300 rows
# Processed 12350 rows
# Processed 12400 rows
# Processed 12450 rows
# Processed 12500 rows
# Processed 12550 rows
# Processed 12600 rows
# Processed 12650 rows
# Processed 12700 rows
# Processed 12750 rows
# Processed 12800 rows
# Processed 12850 rows
# Processed 12900 rows
# Processed 12950 rows
# Processed 13000 rows
# Processed 13050 rows
# Processed 13100 rows
# Processed 13150 rows
# Processed 13200 rows
# Processed 13250 rows
# Processed 13300 rows
# Processed 13350 rows
# Processed 13400 rows
# Processed 13450 rows
# Processed 13500 rows
# Processed 13550 rows
# Processed 13600 rows
# Processed 13650 rows
# Processed 13700 rows
# Processed 13750 rows
# Processed 13800 rows
# Processed 13850 rows
# Processed 13900 rows
# Processed 13950 rows
# Processed 14000 rows
# Processed 14050 rows
# Processed 14100 rows
# Processed 14150 rows
# Processed 14200 rows
# Processed 14250 rows
# Processed 14300 rows
# Processed 14350 rows
# Processed 14400 rows
# Processed 14450 rows
# Processed 14500 rows
# Processed 14550 rows
# Processed 14600 rows
# Processed 14650 rows
# Processed 14700 rows
# Processed 14750 rows
# Processed 14800 rows
# Processed 14850 rows
# Processed 14900 rows
# Processed 14950 rows
# Processed 15000 rows
# Processed 15050 rows
# Processed 15100 rows
# Processed 15150 rows
# Processed 15200 rows
# Processed 15250 rows
# Processed 15300 rows
# Processed 15350 rows
# Processed 15400 rows
# Processed 15450 rows
# Processed 15500 rows
# Processed 15550 rows
# Processed 15600 rows
# Processed 15650 rows
# Processed 15700 rows
# Processed 15750 rows
# Processed 15800 rows
# Processed 15850 rows
# Processed 15900 rows
# Processed 15950 rows
# Processed 16000 rows
# Processed 16050 rows
# Processed 16100 rows
# Processed 16150 rows
# Processed 16200 rows
# Processed 16250 rows
# Processed 16300 rows
# Processed 16350 rows
# Processed 16400 rows
# Processed 16450 rows
# Processed 16500 rows
# Processed 16550 rows
# Processed 16600 rows
# Processed 16650 rows
# Processed 16700 rows
# Processed 16750 rows
# Processed 16800 rows
# Processed 16850 rows
# Processed 16900 rows
# Processed 16950 rows
# Processed 17000 rows
# Processed 17050 rows
# Processed 17100 rows
# Processed 17150 rows
# Processed 17200 rows
# Processed 17250 rows
# Processed 17300 rows
# Processed 17350 rows
# Processed 17400 rows
# Processed 17450 rows
# Processed 17500 rows
# Processed 17550 rows
# Processed 17600 rows
# Processed 17650 rows
# Processed 17700 rows
# Processed 17750 rows
# Processed 17800 rows
# Processed 17850 rows
# Processed 17900 rows
# Processed 17950 rows
# Processed 18000 rows
# Processed 18050 rows
# Processed 18100 rows
# Processed 18150 rows
# Processed 18200 rows
# Processed 18250 rows
# Processed 18300 rows
# Processed 18350 rows
# Processed 18400 rows
# Processed 18450 rows
# Processed 18500 rows
# Processed 18550 rows
# Processed 18600 rows
# Processed 18650 rows
# Processed 18700 rows
# Processed 18750 rows
# Processed 18800 rows
# Processed 18850 rows
# Processed 18900 rows
# Processed 18950 rows
# Processed 19000 rows
# Processed 19050 rows
# Processed 19100 rows
# Processed 19150 rows
# Processed 19200 rows
# Processed 19250 rows
# Processed 19300 rows
# Processed 19350 rows
# Processed 19400 rows
# Processed 19450 rows
# Processed 19500 rows
# Processed 19550 rows
# Processed 19600 rows
# Processed 19650 rows
# Processed 19700 rows
# Processed 19750 rows
# Processed 19800 rows
# Processed 19850 rows
# Processed 19900 rows
# Processed 19950 rows
# Processed 20000 rows
# Processed 20050 rows
# Processed 20100 rows
# Processed 20150 rows
# Processed 20200 rows
# Processed 20250 rows
# Processed 20300 rows
# Processed 20350 rows
# Processed 20400 rows
# Processed 20450 rows
# Processed 20500 rows
# Processed 20550 rows
# Processed 20600 rows
# Processed 20650 rows
# Processed 20700 rows
# Processed 20750 rows
# Processed 20800 rows
# Processed 20850 rows
# Processed 20900 rows
# Processed 20950 rows
# Processed 21000 rows
# Processed 21050 rows
# Processed 21100 rows
# Processed 21150 rows
# Processed 21200 rows
# Processed 21250 rows
# Processed 21300 rows
# Processed 21350 rows
# Processed 21400 rows
# Processed 21450 rows
# Processed 21500 rows
# Processed 21550 rows
# Processed 21600 rows
# Processed 21650 rows
# Processed 21700 rows
# Processed 21750 rows
# Processed 21800 rows
# Processed 21850 rows
# Processed 21900 rows
# Processed 21950 rows
# Processed 22000 rows
# Processed 22050 rows
# Processed 22100 rows
# Processed 22150 rows
# Processed 22200 rows
# Processed 22250 rows
# Processed 22300 rows
# Processed 22350 rows
# Processed 22400 rows
# Processed 22450 rows
# Processed 22500 rows
# Processed 22550 rows
# Processed 22600 rows
# Processed 22650 rows
# Processed 22700 rows
# Processed 22750 rows
# Processed 22800 rows
# Processed 22850 rows
# Processed 22900 rows
# Processed 22950 rows
# Processed 23000 rows
# Processed 23050 rows
# Processed 23100 rows
# Processed 23150 rows
# Processed 23200 rows
# Processed 23250 rows
# Processed 23300 rows
# Processed 23350 rows
# Processed 23400 rows
# Processed 23450 rows
# Processed 23500 rows
# Processed 23550 rows
# Processed 23600 rows
# Processed 23650 rows
# Processed 23700 rows
# Processed 23750 rows
# Processed 23800 rows
# Processed 23850 rows
# Processed 23900 rows
# Processed 23950 rows
# Processed 24000 rows
# Processed 24050 rows
# Processed 24100 rows
# Processed 24150 rows
# Processed 24200 rows
# Processed 24250 rows
# Processed 24300 rows
# Processed 24350 rows
# Processed 24400 rows
# Processed 24450 rows
# Processed 24500 rows
# Processed 24550 rows
# Processed 24600 rows
# Processed 24650 rows
# Processed 24700 rows
# Processed 24750 rows
# Processed 24800 rows
# Processed 24850 rows
# Processed 24900 rows
# Processed 24950 rows
# Processed 25000 rows
# Processed 25050 rows
# Processed 25100 rows
# Processed 25150 rows
# Processed 25200 rows
# Processed 25250 rows
# Processed 25300 rows
# Processed 25350 rows
# Processed 25400 rows
# Processed 25450 rows
# Processed 25500 rows
# Processed 25550 rows
# Processed 25600 rows
# Processed 25650 rows
# Processed 25700 rows
# Processed 25750 rows
# Processed 25800 rows
# Processed 25850 rows
# Processed 25900 rows
# Processed 25950 rows
# Processed 26000 rows
# Processed 26050 rows
# Processed 26100 rows
# Processed 26150 rows
# Processed 26200 rows
# Processed 26250 rows
# Processed 26300 rows
# Processed 26350 rows
# Processed 26400 rows
# Processed 26500 rows
# Processed 26550 rows
# Processed 26600 rows
# Processed 26650 rows
# Processed 26700 rows
# Processed 26750 rows
# Processed 26800 rows
# Processed 26850 rows
# Processed 26900 rows
# Processed 26950 rows
# Processed 27000 rows
# Processed 27050 rows
# Processed 27100 rows
# Processed 27150 rows
# Processed 27200 rows
# Processed 27250 rows
# Processed 27300 rows
# Processed 27350 rows
# Processed 27450 rows
# Processed 27500 rows
# Processed 27550 rows
# Processed 27600 rows
# Processed 27650 rows
# Processed 27700 rows
# Processed 27750 rows
# Processed 27800 rows
# Processed 27850 rows
# Processed 27900 rows
# Processed 27950 rows
# Processed 28000 rows
# Processed 28050 rows
# Processed 28100 rows
# Processed 28150 rows
# Processed 28200 rows
# Processed 28250 rows
# Processed 28300 rows
# Processed 28450 rows
# Processed 28500 rows
# Processed 28550 rows
# Processed 28600 rows
# Processed 28650 rows
# Processed 28700 rows
# Processed 28750 rows
# Processed 28800 rows
# Processed 28850 rows
# Processed 28900 rows
# Processed 28950 rows
# Processed 29000 rows
# Processed 29050 rows
# Processed 29100 rows
# Processed 29150 rows
# Processed 29200 rows
# Processed 29250 rows
# Processed 29300 rows
# Processed 29350 rows
# Processed 29400 rows
# Processed 29450 rows
# Processed 29500 rows
# Processed 29550 rows
# Processed 29600 rows
# Processed 29650 rows
# Processed 29700 rows
# Processed 29750 rows
# Processed 29800 rows
# Processed 29850 rows
# Processed 29900 rows
# Processed 29950 rows
# Processed 30000 rows
# Processed 30050 rows
# Processed 30100 rows
# Processed 30150 rows
# Processed 30200 rows
# Processed 30250 rows
# Processed 30300 rows
# Processed 30400 rows
# Processed 30450 rows
# Processed 30500 rows
# Processed 30550 rows
# Processed 30600 rows
# Processed 30650 rows
# Processed 30700 rows
# Processed 30750 rows
# Processed 30800 rows
# Processed 30850 rows
# Processed 30900 rows
# Processed 31000 rows
# Processed 31050 rows
# Processed 31100 rows
# Processed 31150 rows
# Processed 31200 rows
# Processed 31250 rows
# Processed 31300 rows
# Processed 31350 rows
# Processed 31450 rows
# Processed 31500 rows
# Processed 31550 rows
# Processed 31650 rows
# Processed 31700 rows
# Processed 31750 rows
# Processed 31850 rows
# Processed 31900 rows
# Processed 31950 rows
# Processed 32000 rows
# Processed 32050 rows
# Processed 32100 rows
# Processed 32150 rows
# Processed 32200 rows
# Processed 32300 rows
# Processed 32350 rows
# Processed 32400 rows
# Processed 32450 rows
# Processed 32500 rows
# Processed 32550 rows
# Processed 32600 rows
# Processed 32650 rows
# Processed 32700 rows
# Processed 32800 rows
# Processed 32850 rows
# Processed 32900 rows
# Processed 32950 rows
# Processed 33000 rows
# Processed 33050 rows
# Processed 33100 rows
# Processed 33150 rows
# Processed 33200 rows
# Processed 33250 rows
# Processed 33300 rows
# Processed 33350 rows
# Processed 33400 rows
# Processed 33450 rows
# Processed 33500 rows
# Processed 33550 rows
# Processed 33600 rows
# Processed 33650 rows
# Processed 33700 rows
# Processed 33750 rows
# Processed 33800 rows
# Processed 33850 rows
# Processed 33900 rows
# Processed 33950 rows
# Processed 34000 rows
# Processed 34050 rows
# Processed 34100 rows
# Processed 34150 rows
# Processed 34200 rows
# Processed 34250 rows
# Processed 34300 rows
# Processed 34450 rows
# Processed 34500 rows
# Processed 34550 rows
# Processed 34600 rows
# Processed 34650 rows
# Processed 34700 rows
# Processed 34750 rows
# Processed 34800 rows
# Processed 34850 rows
# Processed 34950 rows
#                        query  \
# 0          petmax бантик 2шт
# 1           0etmax батки 2шт
# 2           etmax бантик 2шт
# 3           9etmax бнатик 2ш
# 4                       бусы
# ...                      ...
# 138015     ингпвирин каспулы
# 138016  crafers печенье 180г
# 138017  craefgs епченье 1? 0
# 138018   craefrs еченье 1г0г
# 138019   rsfres епченье  80г
#
#                                                    markup
# 0       [(0, 6, B-BRAND), (7, 13, B-TYPE), (14, 17, B-...
# 1       [(0, 6, B-BRAND), (7, 12, B-TYPE), (13, 16, B-...
# 2       [(0, 5, B-BRAND), (6, 12, B-TYPE), (13, 16, B-...
# 3       [(0, 6, B-BRAND), (7, 13, B-TYPE), (14, 16, B-...
# 4                                        [(0, 4, B-TYPE)]
# ...                                                   ...
# 138015                [(0, 9, B-BRAND), (10, 17, B-TYPE)]
# 138016  [(0, 7, B-BRAND), (8, 15, B-TYPE), (16, 20, B-...
# 138017  [(0, 7, B-BRAND), (8, 15, B-TYPE), (16, 20, B-...
# 138018  [(0, 7, B-BRAND), (8, 14, B-TYPE), (15, 19, B-...
# 138019  [(0, 6, B-BRAND), (7, 14, B-TYPE), (15, 19, B-...
#
# [138020 rows x 2 columns]

# %% [markdown]
# Перемешка слов

# %%
df_mix = pd.DataFrame()
df_test = df[['query', 'markup']]
for _, row in df_test.iterrows():
    orig_row = pd.DataFrame({'query': [row['query']], 'markup': [row['markup']]})
    df_mix = pd.concat([df_mix, orig_row], ignore_index=True) 
    augmented_texts, augmented_tags = mix_augment(row)
    df_temp = pd.DataFrame({'query': augmented_texts, 'markup': augmented_tags})
    df_mix = pd.concat([df_mix, df_temp], ignore_index=True)
    if _ % 50 == 0:
        print(f"Processed {_} rows")
df_mix
# Out:
# Processed 0 rows
# Processed 50 rows
# Processed 100 rows
# Processed 150 rows
# Processed 200 rows
# Processed 250 rows
# Processed 300 rows
# Processed 350 rows
# Processed 400 rows
# Processed 450 rows
# Processed 500 rows
# Processed 550 rows
# Processed 600 rows
# Processed 650 rows
# Processed 700 rows
# Processed 750 rows
# Processed 800 rows
# Processed 850 rows
# Processed 900 rows
# Processed 950 rows
# Processed 1000 rows
# Processed 1050 rows
# Processed 1100 rows
# Processed 1150 rows
# Processed 1200 rows
# Processed 1250 rows
# Processed 1300 rows
# Processed 1350 rows
# Processed 1400 rows
# Processed 1450 rows
# Processed 1500 rows
# Processed 1550 rows
# Processed 1600 rows
# Processed 1650 rows
# Processed 1700 rows
# Processed 1750 rows
# Processed 1800 rows
# Processed 1850 rows
# Processed 1900 rows
# Processed 1950 rows
# Processed 2000 rows
# Processed 2050 rows
# Processed 2100 rows
# Processed 2150 rows
# Processed 2200 rows
# Processed 2250 rows
# Processed 2300 rows
# Processed 2350 rows
# Processed 2400 rows
# Processed 2450 rows
# Processed 2500 rows
# Processed 2550 rows
# Processed 2600 rows
# Processed 2650 rows
# Processed 2700 rows
# Processed 2750 rows
# Processed 2800 rows
# Processed 2850 rows
# Processed 2900 rows
# Processed 2950 rows
# Processed 3000 rows
# Processed 3050 rows
# Processed 3100 rows
# Processed 3150 rows
# Processed 3200 rows
# Processed 3250 rows
# Processed 3300 rows
# Processed 3350 rows
# Processed 3400 rows
# Processed 3450 rows
# Processed 3500 rows
# Processed 3550 rows
# Processed 3600 rows
# Processed 3650 rows
# Processed 3700 rows
# Processed 3750 rows
# Processed 3800 rows
# Processed 3850 rows
# Processed 3900 rows
# Processed 3950 rows
# Processed 4000 rows
# Processed 4050 rows
# Processed 4100 rows
# Processed 4150 rows
# Processed 4200 rows
# Processed 4250 rows
# Processed 4300 rows
# Processed 4350 rows
# Processed 4400 rows
# Processed 4450 rows
# Processed 4500 rows
# Processed 4550 rows
# Processed 4600 rows
# Processed 4650 rows
# Processed 4700 rows
# Processed 4750 rows
# Processed 4800 rows
# Processed 4850 rows
# Processed 4900 rows
# Processed 4950 rows
# Processed 5000 rows
# Processed 5050 rows
# Processed 5100 rows
# Processed 5150 rows
# Processed 5200 rows
# Processed 5250 rows
# Processed 5300 rows
# Processed 5350 rows
# Processed 5400 rows
# Processed 5450 rows
# Processed 5500 rows
# Processed 5550 rows
# Processed 5600 rows
# Processed 5650 rows
# Processed 5700 rows
# Processed 5750 rows
# Processed 5800 rows
# Processed 5850 rows
# Processed 5900 rows
# Processed 5950 rows
# Processed 6000 rows
# Processed 6050 rows
# Processed 6100 rows
# Processed 6150 rows
# Processed 6200 rows
# Processed 6250 rows
# Processed 6300 rows
# Processed 6350 rows
# Processed 6400 rows
# Processed 6450 rows
# Processed 6500 rows
# Processed 6550 rows
# Processed 6600 rows
# Processed 6650 rows
# Processed 6700 rows
# Processed 6750 rows
# Processed 6800 rows
# Processed 6850 rows
# Processed 6900 rows
# Processed 6950 rows
# Processed 7000 rows
# Processed 7050 rows
# Processed 7100 rows
# Processed 7150 rows
# Processed 7200 rows
# Processed 7250 rows
# Processed 7300 rows
# Processed 7350 rows
# Processed 7400 rows
# Processed 7450 rows
# Processed 7500 rows
# Processed 7550 rows
# Processed 7600 rows
# Processed 7650 rows
# Processed 7700 rows
# Processed 7750 rows
# Processed 7800 rows
# Processed 7850 rows
# Processed 7900 rows
# Processed 7950 rows
# Processed 8000 rows
# Processed 8050 rows
# Processed 8100 rows
# Processed 8150 rows
# Processed 8200 rows
# Processed 8250 rows
# Processed 8300 rows
# Processed 8350 rows
# Processed 8400 rows
# Processed 8450 rows
# Processed 8500 rows
# Processed 8550 rows
# Processed 8600 rows
# Processed 8650 rows
# Processed 8700 rows
# Processed 8750 rows
# Processed 8800 rows
# Processed 8850 rows
# Processed 8900 rows
# Processed 8950 rows
# Processed 9000 rows
# Processed 9050 rows
# Processed 9100 rows
# Processed 9150 rows
# Processed 9200 rows
# Processed 9250 rows
# Processed 9300 rows
# Processed 9350 rows
# Processed 9400 rows
# Processed 9450 rows
# Processed 9500 rows
# Processed 9550 rows
# Processed 9600 rows
# Processed 9650 rows
# Processed 9700 rows
# Processed 9750 rows
# Processed 9800 rows
# Processed 9850 rows
# Processed 9900 rows
# Processed 9950 rows
# Processed 10000 rows
# Processed 10050 rows
# Processed 10100 rows
# Processed 10150 rows
# Processed 10200 rows
# Processed 10250 rows
# Processed 10300 rows
# Processed 10350 rows
# Processed 10400 rows
# Processed 10450 rows
# Processed 10500 rows
# Processed 10550 rows
# Processed 10600 rows
# Processed 10650 rows
# Processed 10700 rows
# Processed 10750 rows
# Processed 10800 rows
# Processed 10850 rows
# Processed 10900 rows
# Processed 10950 rows
# Processed 11000 rows
# Processed 11050 rows
# Processed 11100 rows
# Processed 11150 rows
# Processed 11200 rows
# Processed 11250 rows
# Processed 11300 rows
# Processed 11350 rows
# Processed 11400 rows
# Processed 11450 rows
# Processed 11500 rows
# Processed 11550 rows
# Processed 11600 rows
# Processed 11650 rows
# Processed 11700 rows
# Processed 11750 rows
# Processed 11800 rows
# Processed 11850 rows
# Processed 11900 rows
# Processed 11950 rows
# Processed 12000 rows
# Processed 12050 rows
# Processed 12100 rows
# Processed 12150 rows
# Processed 12200 rows
# Processed 12250 rows
# Processed 12300 rows
# Processed 12350 rows
# Processed 12400 rows
# Processed 12450 rows
# Processed 12500 rows
# Processed 12550 rows
# Processed 12600 rows
# Processed 12650 rows
# Processed 12700 rows
# Processed 12750 rows
# Processed 12800 rows
# Processed 12850 rows
# Processed 12900 rows
# Processed 12950 rows
# Processed 13000 rows
# Processed 13050 rows
# Processed 13100 rows
# Processed 13150 rows
# Processed 13200 rows
# Processed 13250 rows
# Processed 13300 rows
# Processed 13350 rows
# Processed 13400 rows
# Processed 13450 rows
# Processed 13500 rows
# Processed 13550 rows
# Processed 13600 rows
# Processed 13650 rows
# Processed 13700 rows
# Processed 13750 rows
# Processed 13800 rows
# Processed 13850 rows
# Processed 13900 rows
# Processed 13950 rows
# Processed 14000 rows
# Processed 14050 rows
# Processed 14100 rows
# Processed 14150 rows
# Processed 14200 rows
# Processed 14250 rows
# Processed 14300 rows
# Processed 14350 rows
# Processed 14400 rows
# Processed 14450 rows
# Processed 14500 rows
# Processed 14550 rows
# Processed 14600 rows
# Processed 14650 rows
# Processed 14700 rows
# Processed 14750 rows
# Processed 14800 rows
# Processed 14850 rows
# Processed 14900 rows
# Processed 14950 rows
# Processed 15000 rows
# Processed 15050 rows
# Processed 15100 rows
# Processed 15150 rows
# Processed 15200 rows
# Processed 15250 rows
# Processed 15300 rows
# Processed 15350 rows
# Processed 15400 rows
# Processed 15450 rows
# Processed 15500 rows
# Processed 15550 rows
# Processed 15600 rows
# Processed 15650 rows
# Processed 15700 rows
# Processed 15750 rows
# Processed 15800 rows
# Processed 15850 rows
# Processed 15900 rows
# Processed 15950 rows
# Processed 16000 rows
# Processed 16050 rows
# Processed 16100 rows
# Processed 16150 rows
# Processed 16200 rows
# Processed 16250 rows
# Processed 16300 rows
# Processed 16350 rows
# Processed 16400 rows
# Processed 16450 rows
# Processed 16500 rows
# Processed 16550 rows
# Processed 16600 rows
# Processed 16650 rows
# Processed 16700 rows
# Processed 16750 rows
# Processed 16800 rows
# Processed 16850 rows
# Processed 16900 rows
# Processed 16950 rows
# Processed 17000 rows
# Processed 17050 rows
# Processed 17100 rows
# Processed 17150 rows
# Processed 17200 rows
# Processed 17250 rows
# Processed 17300 rows
# Processed 17350 rows
# Processed 17400 rows
# Processed 17450 rows
# Processed 17500 rows
# Processed 17550 rows
# Processed 17600 rows
# Processed 17650 rows
# Processed 17700 rows
# Processed 17750 rows
# Processed 17800 rows
# Processed 17850 rows
# Processed 17900 rows
# Processed 17950 rows
# Processed 18000 rows
# Processed 18050 rows
# Processed 18100 rows
# Processed 18150 rows
# Processed 18200 rows
# Processed 18250 rows
# Processed 18300 rows
# Processed 18350 rows
# Processed 18400 rows
# Processed 18450 rows
# Processed 18500 rows
# Processed 18550 rows
# Processed 18600 rows
# Processed 18650 rows
# Processed 18700 rows
# Processed 18750 rows
# Processed 18800 rows
# Processed 18850 rows
# Processed 18900 rows
# Processed 18950 rows
# Processed 19000 rows
# Processed 19050 rows
# Processed 19100 rows
# Processed 19150 rows
# Processed 19200 rows
# Processed 19250 rows
# Processed 19300 rows
# Processed 19350 rows
# Processed 19400 rows
# Processed 19450 rows
# Processed 19500 rows
# Processed 19550 rows
# Processed 19600 rows
# Processed 19650 rows
# Processed 19700 rows
# Processed 19750 rows
# Processed 19800 rows
# Processed 19850 rows
# Processed 19900 rows
# Processed 19950 rows
# Processed 20000 rows
# Processed 20050 rows
# Processed 20100 rows
# Processed 20150 rows
# Processed 20200 rows
# Processed 20250 rows
# Processed 20300 rows
# Processed 20350 rows
# Processed 20400 rows
# Processed 20450 rows
# Processed 20500 rows
# Processed 20550 rows
# Processed 20600 rows
# Processed 20650 rows
# Processed 20700 rows
# Processed 20750 rows
# Processed 20800 rows
# Processed 20850 rows
# Processed 20900 rows
# Processed 20950 rows
# Processed 21000 rows
# Processed 21050 rows
# Processed 21100 rows
# Processed 21150 rows
# Processed 21200 rows
# Processed 21250 rows
# Processed 21300 rows
# Processed 21350 rows
# Processed 21400 rows
# Processed 21450 rows
# Processed 21500 rows
# Processed 21550 rows
# Processed 21600 rows
# Processed 21650 rows
# Processed 21700 rows
# Processed 21750 rows
# Processed 21800 rows
# Processed 21850 rows
# Processed 21900 rows
# Processed 21950 rows
# Processed 22000 rows
# Processed 22050 rows
# Processed 22100 rows
# Processed 22150 rows
# Processed 22200 rows
# Processed 22250 rows
# Processed 22300 rows
# Processed 22350 rows
# Processed 22400 rows
# Processed 22450 rows
# Processed 22500 rows
# Processed 22550 rows
# Processed 22600 rows
# Processed 22650 rows
# Processed 22700 rows
# Processed 22750 rows
# Processed 22800 rows
# Processed 22850 rows
# Processed 22900 rows
# Processed 22950 rows
# Processed 23000 rows
# Processed 23050 rows
# Processed 23100 rows
# Processed 23150 rows
# Processed 23200 rows
# Processed 23250 rows
# Processed 23300 rows
# Processed 23350 rows
# Processed 23400 rows
# Processed 23450 rows
# Processed 23500 rows
# Processed 23550 rows
# Processed 23600 rows
# Processed 23650 rows
# Processed 23700 rows
# Processed 23750 rows
# Processed 23800 rows
# Processed 23850 rows
# Processed 23900 rows
# Processed 23950 rows
# Processed 24000 rows
# Processed 24050 rows
# Processed 24100 rows
# Processed 24150 rows
# Processed 24200 rows
# Processed 24250 rows
# Processed 24300 rows
# Processed 24350 rows
# Processed 24400 rows
# Processed 24450 rows
# Processed 24500 rows
# Processed 24550 rows
# Processed 24600 rows
# Processed 24650 rows
# Processed 24700 rows
# Processed 24750 rows
# Processed 24800 rows
# Processed 24850 rows
# Processed 24900 rows
# Processed 24950 rows
# Processed 25000 rows
# Processed 25050 rows
# Processed 25100 rows
# Processed 25150 rows
# Processed 25200 rows
# Processed 25250 rows
# Processed 25300 rows
# Processed 25350 rows
# Processed 25400 rows
# Processed 25450 rows
# Processed 25500 rows
# Processed 25550 rows
# Processed 25600 rows
# Processed 25650 rows
# Processed 25700 rows
# Processed 25750 rows
# Processed 25800 rows
# Processed 25850 rows
# Processed 25900 rows
# Processed 25950 rows
# Processed 26000 rows
# Processed 26050 rows
# Processed 26100 rows
# Processed 26150 rows
# Processed 26200 rows
# Processed 26250 rows
# Processed 26300 rows
# Processed 26350 rows
# Processed 26400 rows
# Processed 26500 rows
# Processed 26550 rows
# Processed 26600 rows
# Processed 26650 rows
# Processed 26700 rows
# Processed 26750 rows
# Processed 26800 rows
# Processed 26850 rows
# Processed 26900 rows
# Processed 26950 rows
# Processed 27000 rows
# Processed 27050 rows
# Processed 27100 rows
# Processed 27150 rows
# Processed 27200 rows
# Processed 27250 rows
# Processed 27300 rows
# Processed 27350 rows
# Processed 27450 rows
# Processed 27500 rows
# Processed 27550 rows
# Processed 27600 rows
# Processed 27650 rows
# Processed 27700 rows
# Processed 27750 rows
# Processed 27800 rows
# Processed 27850 rows
# Processed 27900 rows
# Processed 27950 rows
# Processed 28000 rows
# Processed 28050 rows
# Processed 28100 rows
# Processed 28150 rows
# Processed 28200 rows
# Processed 28250 rows
# Processed 28300 rows
# Processed 28450 rows
# Processed 28500 rows
# Processed 28550 rows
# Processed 28600 rows
# Processed 28650 rows
# Processed 28700 rows
# Processed 28750 rows
# Processed 28800 rows
# Processed 28850 rows
# Processed 28900 rows
# Processed 28950 rows
# Processed 29000 rows
# Processed 29050 rows
# Processed 29100 rows
# Processed 29150 rows
# Processed 29200 rows
# Processed 29250 rows
# Processed 29300 rows
# Processed 29350 rows
# Processed 29400 rows
# Processed 29450 rows
# Processed 29500 rows
# Processed 29550 rows
# Processed 29600 rows
# Processed 29650 rows
# Processed 29700 rows
# Processed 29750 rows
# Processed 29800 rows
# Processed 29850 rows
# Processed 29900 rows
# Processed 29950 rows
# Processed 30000 rows
# Processed 30050 rows
# Processed 30100 rows
# Processed 30150 rows
# Processed 30200 rows
# Processed 30250 rows
# Processed 30300 rows
# Processed 30400 rows
# Processed 30450 rows
# Processed 30500 rows
# Processed 30550 rows
# Processed 30600 rows
# Processed 30650 rows
# Processed 30700 rows
# Processed 30750 rows
# Processed 30800 rows
# Processed 30850 rows
# Processed 30900 rows
# Processed 31000 rows
# Processed 31050 rows
# Processed 31100 rows
# Processed 31150 rows
# Processed 31200 rows
# Processed 31250 rows
# Processed 31300 rows
# Processed 31350 rows
# Processed 31450 rows
# Processed 31500 rows
# Processed 31550 rows
# Processed 31650 rows
# Processed 31700 rows
# Processed 31750 rows
# Processed 31850 rows
# Processed 31900 rows
# Processed 31950 rows
# Processed 32000 rows
# Processed 32050 rows
# Processed 32100 rows
# Processed 32150 rows
# Processed 32200 rows
# Processed 32300 rows
# Processed 32350 rows
# Processed 32400 rows
# Processed 32450 rows
# Processed 32500 rows
# Processed 32550 rows
# Processed 32600 rows
# Processed 32650 rows
# Processed 32700 rows
# Processed 32800 rows
# Processed 32850 rows
# Processed 32900 rows
# Processed 32950 rows
# Processed 33000 rows
# Processed 33050 rows
# Processed 33100 rows
# Processed 33150 rows
# Processed 33200 rows
# Processed 33250 rows
# Processed 33300 rows
# Processed 33350 rows
# Processed 33400 rows
# Processed 33450 rows
# Processed 33500 rows
# Processed 33550 rows
# Processed 33600 rows
# Processed 33650 rows
# Processed 33700 rows
# Processed 33750 rows
# Processed 33800 rows
# Processed 33850 rows
# Processed 33900 rows
# Processed 33950 rows
# Processed 34000 rows
# Processed 34050 rows
# Processed 34100 rows
# Processed 34150 rows
# Processed 34200 rows
# Processed 34250 rows
# Processed 34300 rows
# Processed 34450 rows
# Processed 34500 rows
# Processed 34550 rows
# Processed 34600 rows
# Processed 34650 rows
# Processed 34700 rows
# Processed 34750 rows
# Processed 34800 rows
# Processed 34850 rows
# Processed 34950 rows
#                        query  \
# 0          petmax бантик 2шт
# 1              бантик petmax
# 2              petmax бантик
# 3          бантик petmax 2шт
# 4          бантик 2шт petmax
# ...                      ...
# 124982       печенье crafers
# 124983       crafers печенье
# 124984  печенье crafers 180г
# 124985  печенье 180г crafers
# 124986          печенье 180г
#
#                                                    markup
# 0       [(0, 6, B-BRAND), (7, 13, B-TYPE), (14, 17, B-...
# 1                      [(0, 6, B-TYPE), (7, 13, B-BRAND)]
# 2                      [(0, 6, B-BRAND), (7, 13, B-TYPE)]
# 3       [(0, 6, B-TYPE), (7, 13, B-BRAND), (14, 17, B-...
# 4       [(0, 6, B-TYPE), (7, 10, B-VOLUME), (11, 17, B...
# ...                                                   ...
# 124982                 [(0, 7, B-TYPE), (8, 15, B-BRAND)]
# 124983                 [(0, 7, B-BRAND), (8, 15, B-TYPE)]
# 124984  [(0, 7, B-TYPE), (8, 15, B-BRAND), (16, 20, B-...
# 124985  [(0, 7, B-TYPE), (8, 12, B-VOLUME), (13, 20, B...
# 124986                [(0, 7, B-TYPE), (8, 12, B-VOLUME)]
#
# [124987 rows x 2 columns]

# %% [markdown]
# Перемешка слов (к df с опечатками)

# %%
df_aug_mix = pd.DataFrame()
for _, row in df_aug.iterrows():
    orig_row = pd.DataFrame({'query': [row['query']], 'markup': [row['markup']]})
    df_aug_mix = pd.concat([df_aug_mix, orig_row], ignore_index=True) 
    augmented_texts, augmented_tags = mix_augment(row)
    df_temp = pd.DataFrame({'query': augmented_texts, 'markup': augmented_tags})
    df_aug_mix = pd.concat([df_aug_mix, df_temp], ignore_index=True)

df_aug_mix
# Out:
#                   query                                             markup
# 0     petmax бантик 2шт  [(0, 6, B-BRAND), (7, 13, B-TYPE), (14, 17, B-...
# 1         бантик petmax                 [(0, 6, B-TYPE), (7, 13, B-BRAND)]
# 2         petmax бантик                 [(0, 6, B-BRAND), (7, 13, B-TYPE)]
# 3     бантик petmax 2шт  [(0, 6, B-TYPE), (7, 13, B-BRAND), (14, 17, B-...
# 4     бантик 2шт petmax  [(0, 6, B-TYPE), (7, 10, B-VOLUME), (11, 17, B...
# ..                  ...                                                ...
# 123      анконрчник ekf               [(0, 10, B-TYPE), (11, 14, B-BRAND)]
# 124      ekf анконрчник                 [(0, 3, B-BRAND), (4, 14, B-TYPE)]
# 125  анконрчник ekf 50ш  [(0, 10, B-TYPE), (11, 14, B-BRAND), (15, 18, ...
# 126  анконрчник 50ш ekf  [(0, 10, B-TYPE), (11, 14, B-VOLUME), (15, 18,...
# 127      анконрчник 50ш              [(0, 10, B-TYPE), (11, 14, B-VOLUME)]
#
# [128 rows x 2 columns]

# %%
# df_aug.to_excel('ofd_aug.xlsx', index=False)
df_aug.to_csv('ofd_aug.csv', encoding="utf-8-sig", index=False)
# df_mix.to_excel('ofd_mix.xlsx', index=False)
df_mix.to_csv('ofd_mix.csv', encoding="utf-8-sig", index=False)
# df_aug_mix.to_excel('ofd_aug_mix.xlsx', index=False)
df_aug_mix = pd.concat([df_aug, df_mix], ignore_index=True)
df_aug_mix.to_csv('ofd_aug_mix.csv', encoding="utf-8-sig", index=False)
